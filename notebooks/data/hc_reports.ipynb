# %%
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://www.canada.ca/en/health-canada/corporate/transparency/corporate-management-reporting/evaluation.html'  #first page to scrape
response = requests.get(url)
content = response.content
soup = BeautifulSoup(content, 'html.parser') #load html of the main site

hrefs = []
names = []

# %%
eval_patterns = [
    'evaluation/results-',
    'evaluation/summary',
    'evaluation-reports/',
    'evaluations/',
    'reporting/summary',
    'reporting/evaluation',
    'publications.gc.ca/'
]
def eval_url(url, patterns=eval_patterns):
    for pattern in patterns:
        if pattern in url:
            return 'https://www.canada.ca/' + url
    return False

# %%
for link in soup.find_all('a'): #iterate through all links of the mainsite url (for each year)
    href = link.get('href') # get a list of sub-urls for reports for each year
    if href and (href := eval_url(href)):
        hrefs.append(href)
        names.append(link.text)

hrefs = list(set(hrefs)) #remove duplicates

# %%
import os
import glob
def clear_folder(folder):
    for file in os.listdir(folder):
        file_path = os.path.join(folder, file)
        if os.path.isfile(file_path):
            os.unlink(file_path)
base_dir = '../../data/raw'
clear_folder(base_dir)

# %%
from bs4 import BeautifulSoup
import requests

def load_full_text(url):
    # Make a request to the URL and retrieve the HTML content
    response = requests.get(url)
    content = response.content

    # Parse the HTML content
    soup = BeautifulSoup(content, 'html.parser')

    # Extract all the text
    section_identifier = 'main[property="mainContentOfPage"][resource="#wb-main"][typeof="WebPageElement"][class="container"]'
    section = soup.select_one(section_identifier) #select texts only from a specific section
    all_text = section.get_text()
    return all_text

success = 0
for i, url in enumerate(hrefs):
    name = names[i]
    #get content
    try:
        full_text = load_full_text(url)
    except Exception as e:
        print(f'{str(i).zfill(3)} - Failed to load "{url}"')
        print(e)
        continue
    #write content
    try:
        fp = open(f'{base_dir}/hc_{str(i).zfill(3)}_{name}.txt', 'w') #write each evaluation report into a separate .txt file
        fp.write(full_text)
        fp.close()
        success += 1
        print(f'{str(i).zfill(3)} - Successfully wrote "{name}"')
    except Exception as e:
        print(f'{str(i).zfill(3)} - Failed to write "{name}"')
        print(e)
        fp.close()
        if os.path.exists(fp.name):
            os.remove(fp.name)
print(f'Successfully wrote {success}/{len(hrefs)} files')
# Out:
# 000 - Successfully wrote "At a Glance - Departmental Evaluation Plan for Health Canada, 2022-23 to 2026-27"
# 001 - Successfully wrote "At a Glance: Departmental Evaluation Plan for Health Canada 2021-22 to 2025-26"
# 002 - Successfully wrote "At a Glance: Departmental Evaluation Plan for Health Canada 2020-21 to 2024-25"
# 003 - Successfully wrote "At a Glance- Departmental Evaluation Plan for the Public Health Agency of Canada and Health Canada, 2019-20 to 2023-24"
# 004 - Successfully wrote "Results at a glance"
# 005 - Successfully wrote "Evaluation report"
# 006 - Successfully wrote "Results at a glance"
# 007 - Successfully wrote "Evaluation report"
# 008 - Successfully wrote "Results at a glance"
# 009 - Successfully wrote "Evaluation Report"
# 010 - Successfully wrote "Results at a glance"
# 011 - Successfully wrote "Evaluation Report"
# 012 - Failed to write "Results at a glance"
# 'charmap' codec can't encode character '\u2212' in position 243849: character maps to <undefined>
# 013 - Successfully wrote "Evaluation Report"
# 014 - Successfully wrote "Results at a glance"
# 015 - Successfully wrote "Results at a glance"
# 016 - Successfully wrote "Evaluation Report"
# 017 - Successfully wrote "Results at a glance"
# 018 - Successfully wrote "Evaluation Report"
# 019 - Failed to write "Results at a glance"
# 'charmap' codec can't encode character '\u2212' in position 80791: character maps to <undefined>
# 020 - Successfully wrote "Evaluation Report"
# 021 - Successfully wrote "Results at a glance"
# 022 - Failed to load "https://www.canada.ca/https://nrc.canada.ca/en/corporate/planning-reporting/summary-report-evaluation-genomics-research-development-initiative-shared-priority-projects"
# 'NoneType' object has no attribute 'get_text'
# 023 - Successfully wrote "Results at a glance"
# 024 - Successfully wrote "Evaluation Report"
# 025 - Successfully wrote "Results at a glance"
# 026 - Successfully wrote "Evaluation Report"
# 027 - Successfully wrote "Evaluation Report"
# 028 - Successfully wrote "Summary Report"
# 029 - Successfully wrote "Audit and Evaluation Report"
# 030 - Successfully wrote "Results at a glance"
# 031 - Successfully wrote "Evaluation report"
# 032 - Successfully wrote "Results at a glance"
# 033 - Successfully wrote "Evaluation report"
# 034 - Failed to write "Evaluation report"
# 'charmap' codec can't encode character '\u03b2' in position 48088: character maps to <undefined>
# 035 - Successfully wrote "CMP: Results at a Glance"
# 036 - Failed to load "https://www.canada.ca/http://publications.gc.ca/site/eng/9.866148/publication.html"
# 'NoneType' object has no attribute 'get_text'
# 037 - Successfully wrote "Results at a Glance"
# 038 - Failed to write "Evaluation report"
# 'charmap' codec can't encode character '\u03b1' in position 231634: character maps to <undefined>
# 039 - Successfully wrote "Results at a Glance"
# 040 - Successfully wrote "Evaluation report"
# 041 - Successfully wrote "Results at a glance"
# 042 - Failed to load "https://www.canada.ca/http://www.inspection.gc.ca/about-the-cfia/accountability/other-activities/audits-reviews-and-evaluations/evaluation-of-the-bse-management-program/eng/1419253150734/1419253153906"
# 'NoneType' object has no attribute 'get_text'
# 043 - Successfully wrote "Results at a glance"
# 044 - Successfully wrote "Evaluation report"
# 045 - Failed to write "Results at a glance"
# 'charmap' codec can't encode character '\u2010' in position 187852: character maps to <undefined>
# 046 - Successfully wrote "Evaluation report"
# 047 - Failed to write "Results at a glance"
# 'charmap' codec can't encode character '\u2010' in position 149636: character maps to <undefined>
# 048 - Failed to load "https://www.canada.ca/https://www.nrc-cnrc.gc.ca/eng/about/planning_reporting/evaluation/2016_2017/grdi.html"
# 'NoneType' object has no attribute 'get_text'
# 049 - Successfully wrote "Results at a glance"
# 050 - Failed to write "Evaluation report"
# 'charmap' codec can't encode character '\u2212' in position 19789: character maps to <undefined>
# 051 - Successfully wrote "Results at a Glance"
# 052 - Successfully wrote "Evaluation Report"
# 053 - Successfully wrote "Health Canada Statement"
# 054 - Successfully wrote "Result at a Glance"
# 055 - Failed to write "Evaluation Report"
# 'charmap' codec can't encode character '\u2265' in position 38113: character maps to <undefined>
# 056 - Successfully wrote "Management Response and Action Plan"
# 057 - Successfully wrote "Result at a Glance"
# 058 - Successfully wrote "Evaluation Report"
# 059 - Successfully wrote "Results at a Glance"
# 060 - Successfully wrote "Evaluation Report"
# 061 - Successfully wrote "Results at a Glance"
# 062 - Successfully wrote "Evaluation Report"
# 063 - Successfully wrote "Results at a Glance"
# 064 - Successfully wrote "Evaluation Report"
# 065 - Successfully wrote "Horizontal Evaluation of the Genomics R&D Initiative"
# 066 - Failed to write "Results at a Glance - Evaluation of the eHealth Infostructure Program 2011-2012 to 2015-2016"
# 'charmap' codec can't encode character '\u2010' in position 111532: character maps to <undefined>
# 067 - Successfully wrote "Evaluation of the eHealth Infostructure Program 2011-2012 to 2015-2016"
# 068 - Successfully wrote "Results at a Glance - Evaluation of Health Canada's First Nations Health Facilities Program 2010-2011 to 2014-2015"
# 069 - Failed to load "https://www.canada.ca/https://nrc.canada.ca/en/corporate/planning-reporting/evaluation-grdi-shared-priority-projects"
# 'NoneType' object has no attribute 'get_text'
# 070 - Successfully wrote "Results at a Glance - Evaluation of the Official Languages Health Contribution Program 2012-2013 to 2014-2015"
# 071 - Successfully wrote "Evaluation of the Official Languages Health Contribution Program 2012-2013 to 2014-2015"
# 072 - Successfully wrote "Results at a Glance - Evaluation of the Canadian Agency for Drugs and Technologies in Health Activities 2012-2013 to 2015-2016"
# 073 - Failed to write "Evaluation of the Canadian Agency for Drugs and Technologies in Health Activities 2012-2013 to 2015-2016"
# 'charmap' codec can't encode character '\x97' in position 20012: character maps to <undefined>
# 074 - Failed to write "Results at a Glance - Evaluation of the Federal Tobacco Control Strategy 2012-2013 to 2015-2016"
# 'charmap' codec can't encode character '\u2012' in position 1767: character maps to <undefined>
# 075 - Successfully wrote "Evaluation of the Federal Tobacco Control Strategy 2012-2013 to 2015-2016"
# 076 - Successfully wrote "Results at a Glance - Evaluation of the Contribution to Brain Canada Foundation's Canada Brain Research Fund 2011-2012 to 2015-2016"
# 077 - Successfully wrote "Evaluation of the Contribution to Brain Canada Foundation's Canada Brain Research Fund 2011-2012 to 2015-2016"
# 078 - Failed to write "Results at a glance - Evaluation of Health Canada's First Nations and Inuit Health Branch Environmental Public Health Program 2010-11 to 2014-15"
# 'charmap' codec can't encode character '\u202f' in position 172178: character maps to <undefined>
# 079 - Successfully wrote "Evaluation of Health Canada's First Nations and Inuit Health Branch's Environmental Public Health Program 2010-11 to 2014-15"
# 080 - Failed to write "Results at a Glance - Evaluation of the First Nations and Inuit Health Branch's Health Planning and Quality Management Activities 2010-2011 to 2014-2015"
# 'charmap' codec can't encode character '\u01c2' in position 17728: character maps to <undefined>
# 081 - Successfully wrote "Evaluation of the First Nations and Inuit Health Branch's Health Planning and Quality Management Activities - 2010-2011 to 2014-2015"
# 082 - Failed to write "Results at a Glance - Evaluation of Health Canada's Radiation Protection Activities 2010-2011 to 2014-2015"
# 'charmap' codec can't encode character '\ufb02' in position 62170: character maps to <undefined>
# 083 - Successfully wrote "Evaluation of Health Canada's Radiation Protection Activities 2010-2011 to 2014-2015"
# 084 - Successfully wrote "Evaluation of the First Nations and Inuit Mental Wellness Programs 2010-2011 to 2014-2015"
# 085 - Successfully wrote "Evaluation of the Natural Health Products Program 2010-2011 to 2014-2015"
# 086 - Successfully wrote "Evaluation of Mental Health and Mental Illness Activities of Health Canada and the Public Health Agency of Canada 2010-2011 to 2014-2015"
# 087 - Failed to write "Evaluation of the First Nations and Inuit Health Branch's Health Services Integration Fund 2010-2011 to 2014-2015"
# 'charmap' codec can't encode character '\u2011' in position 93573: character maps to <undefined>
# 088 - Successfully wrote "Evaluation of the Canadian Centre on Substance Abuse's Named Grant Activities 2011-2012 to 2014-2015"
# 089 - Successfully wrote "Evaluation of the Canadian Partnership Against Cancer Activities 2012-2013 to 2015-2016"
# 090 - Successfully wrote "Evaluation of the Pesticide Program 2010-2011 to 2013-2014"
# 091 - Successfully wrote "Evaluation of Phase II of the Chemicals Management Plan 2011-2012 to 2015-2016"
# 092 - Successfully wrote "Evaluation of the Nutrition Policy and Promotion Program 2009-2010 to 2014-2015"
# 093 - Failed to write "Evaluation of the Health Information Initiative 2012-2013 to 2014-2015"
# 'charmap' codec can't encode character '\u2212' in position 66579: character maps to <undefined>
# 094 - Successfully wrote "Evaluation of the Canadian HIV Vaccine Initiative 2009-2010 to 2014-2015"
# 095 - Successfully wrote "Evaluation of the First Nations and Inuit Health Branch Communicable Disease Control and Management Programs 2008-2009 to 2013-2014"
# 096 - Successfully wrote "Evaluation of the Healthy Living (2010-2011 to 2012-2013) and Healthy Child Development Clusters (2008-2009 to 2012-2013)"
# 097 - Successfully wrote "Evaluation of Employee Assistance Services 2009-2010 to 2013-2014"
# 098 - Successfully wrote "Evaluation of the Bovine Spongiform Encephalopathy (BSE) Management Program"
# 099 - Successfully wrote "Evaluation of the Food and Consumer Safety Action Plan 2008-2009 to 2012-2013"
# 100 - Successfully wrote "Evaluation of the Biologics Program 1999-2000 to 2012-2013"
# 101 - Failed to write "Evaluation of the Drug Strategy Community Initiatives Fund 2008-2009 to 2012-2013"
# 'charmap' codec can't encode character '\u03b1' in position 209050: character maps to <undefined>
# 102 - Successfully wrote "Evaluation of the Human Drug Program 1999-2000 to 2011-2012"
# 103 - Successfully wrote "Synthesis Evaluation of Transfer Payments to Pan-Canadian Organizations 2008-2009 to 2012-2013"
# 104 - Successfully wrote "Evaluation of the Medical Devices Program 1999-2000 to 2011-2012"
# 105 - Successfully wrote "Evaluation for the Action Plan to Protect Human health from Environmental Contaminants 2008-2009 to 2012-2013"
# 106 - Failed to write "Evaluation of the Drug Treatment Funding Program"
# 'charmap' codec can't encode character '\u2010' in position 257651: character maps to <undefined>
# 107 - Successfully wrote "Evaluation of the Veterinary Drugs Program 1999 to 2012"
# 108 - Successfully wrote "Evaluation of Canadian Blood Services Grant and Contribution Programs 2008-2009 to 2012-2013"
# 109 - Successfully wrote "Evaluation of the Consumer Products Final Report September 2013"
# 110 - Failed to write "Evaluation of the First Nations and Inuit Home and Community Care Program 2008-2009 to 2011-2012"
# 'charmap' codec can't encode character '\u2265' in position 222457: character maps to <undefined>
# 111 - Successfully wrote "Evaluation of the First Nations and Inuit Health Human Resources Program 2008-09 to 2012-13"
# 112 - Successfully wrote "Evaluation of the Health Care Policy Contribution Program, September 2013"
# 113 - Failed to write "Evaluation of the First Nations Clinical and Client Care Program 2005-2006 to 2011-2012"
# 'charmap' codec can't encode character '\u2193' in position 150389: character maps to <undefined>
# 114 - Successfully wrote "Summative Evaluation of the Bovine Spongiform Encephalopathy (BSE) I and II Initiatives - June 2013"
# 115 - Successfully wrote "Evaluation of the First Nations National Nursing Innovation Strategy Program 2008-2009 to 2011-2012"
# 116 - Successfully wrote "Evaluation of the Health Information Initiative 2007-2008 to 2011-2012 - June 2013"
# 117 - Failed to write "Evaluation of the Food Safety and Nutrition Quality Program 1999-2000 to 2011-2012"
# 'charmap' codec can't encode character '\u0101' in position 148601: character maps to <undefined>
# 118 - Successfully wrote "Evaluation of the Official Languages Health Contribution Program 2008-2012"
# 119 - Successfully wrote "Federal Tobacco Control Strategy 2001-2011- Horizontal Evaluation - Final Report, June 2012"
# 120 - Successfully wrote "First Nations BC Tripartite Contribution Agreements - Evaluation 2007-08 to 2011-12"
# 121 - Failed to write "First Nations and Inuit Mental Health and Addictions - Cluster Evaluation 2005/06 - 2009/10"
# [Errno 2] No such file or directory: '../../data/raw/hc_121_First Nations and Inuit Mental Health and Addictions - Cluster Evaluation 2005/06 - 2009/10.txt'
# 122 - Failed to write "First Nations and Inuit Health Facilities and Capital Program - Cluster Evaluation - March 2012"
# 'charmap' codec can't encode character '\u221a' in position 34377: character maps to <undefined>
# 123 - Failed to write "Office of Nutrition Policy and Promotion - Evaluation - March 2012"
# 'charmap' codec can't encode character '\u2010' in position 276148: character maps to <undefined>
# Successfully wrote 95/124 files
